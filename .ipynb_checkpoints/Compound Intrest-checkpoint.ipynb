# %%
import pandas as pd
import numpy as np

# %%
x = np.arange(0, 50, 0.1)
x = np.concatenate((x[:500], x[:200], x[:200], x[:200]))

# %%
y1 = np.arange(0.01, 1, 0.01)
y2 = np.arange(1, 100)
y3 = np.arange(100, 1000)
y4 = np.arange(1000, 10000)
y4 = np.arange(1000, 100000)
y5 = np.arange(1000000, 10000000)

np.random.shuffle(y1)
np.random.shuffle(y2)
np.random.shuffle(y3)
np.random.shuffle(y4)
np.random.shuffle(y5)

# %%
y = np.concatenate((y1[:1], y2[:10], y3[:20], y4[:140], y5[:20]))

# %%
all_numbers = np.transpose([np.tile(x, len(y)), np.repeat(y, len(x))])
df = pd.DataFrame(all_numbers)
# df=df[df[0] < df[1]]
df = df.sample(frac=1)[:20000].reset_index(drop=True)

# %%
df[0] = df[0].apply(lambda x: '{0:.1f}'.format(x)).astype(str)
df[1] = df[1].apply(lambda x: '{0:.1f}'.format(x)).astype(str)

# %%
df[3] = np.random.randint(1,12, len(df))

# %%
df['Question'] = + df[1] + "$ at " + df[0] + "% for " + df[3].astype(str) + " years"

# %%
df[0] = df[0].astype(float)
df[1] = df[1].astype(float)
df[3] = df[3].astype(float)

# %%
(1 + (df[0]/100)) ** ()
# Out:
# 0        1.084
# 1        1.170
# 2        1.020
# 3        1.142
# 4        1.345
# 5        1.055
# 6        1.074
# 7        1.138
# 8        1.014
# 9        1.425
# 10       1.060
# 11       1.174
# 12       1.025
# 13       1.038
# 14       1.118
# 15       1.148
# 16       1.388
# 17       1.068
# 18       1.359
# 19       1.179
# 20       1.162
# 21       1.109
# 22       1.275
# 23       1.085
# 24       1.142
# 25       1.064
# 26       1.126
# 27       1.093
# 28       1.319
# 29       1.467
#          ...
# 19970    1.088
# 19971    1.154
# 19972    1.414
# 19973    1.049
# 19974    1.147
# 19975    1.252
# 19976    1.127
# 19977    1.083
# 19978    1.025
# 19979    1.054
# 19980    1.004
# 19981    1.423
# 19982    1.031
# 19983    1.224
# 19984    1.012
# 19985    1.110
# 19986    1.242
# 19987    1.097
# 19988    1.024
# 19989    1.002
# 19990    1.055
# 19991    1.193
# 19992    1.053
# 19993    1.262
# 19994    1.153
# 19995    1.141
# 19996    1.459
# 19997    1.253
# 19998    1.240
# 19999    1.469
# Name: 0, Length: 20000, dtype: float64

# %%
df['Monthly'].astype(int)
# Out:
# 0         134331
# 1         880768
# 2        6123934
# 3        1260076
# 4          50440
# 5        9703247
# 6        4824553
# 7         280127
# 8        5138451
# 9         154843
# 10        692895
# 11        701970
# 12        836302
# 13        190037
# 14         90083
# 15       1966880
# 16       8755728
# 17       3011931
# 18         60620
# 19         60620
# 20           851
# 21           426
# 22        493442
# 23        685077
# 24       3011931
# 25        644574
# 26           799
# 27            50
# 28        284011
# 29        259520
#           ...
# 19970     691406
# 19971    6794540
# 19972    1259118
# 19973    9041629
# 19974        258
# 19975    4975105
# 19976     787586
# 19977     397359
# 19978    2781102
# 19979     734583
# 19980     147499
# 19981        399
# 19982      57343
# 19983     469987
# 19984        319
# 19985    5421755
# 19986      61204
# 19987     880768
# 19988     884568
# 19989    4946088
# 19990    7191746
# 19991         39
# 19992     150552
# 19993     203647
# 19994        258
# 19995     301233
# 19996    9538410
# 19997    1780464
# 19998    7191746
# 19999     749006
# Name: Monthly, Length: 20000, dtype: int64

# %%
df[['Question', 'Answer']].sample(frac=1).to_csv("percentage.csv", index=None, header=None)

# %%
df
# Out:
#          0          1           Question      Answer
# 0      2.2  3410441.0  2.2% of 3410441.0  75029.7020
# 1      2.9       18.0       2.9% of 18.0      0.5220
# 2      3.4   352118.0   3.4% of 352118.0  11972.0120
# 3      2.6   187185.0   2.6% of 187185.0   4866.8100
# 4      3.6   988306.0   3.6% of 988306.0  35579.0160
# 5      8.2   913275.0   8.2% of 913275.0  74888.5500
# 6      1.1  7077664.0  1.1% of 7077664.0  77854.3040
# 7      4.4       87.0       4.4% of 87.0      3.8280
# 8      6.8      346.0      6.8% of 346.0     23.5280
# 9      2.5       57.0       2.5% of 57.0      1.4250
# 10     5.4        0.0        5.4% of 0.0      0.0000
# 11     1.3   398736.0   1.3% of 398736.0   5183.5680
# 12     6.9   760929.0   6.9% of 760929.0  52504.1010
# 13     1.3      924.0      1.3% of 924.0     12.0120
# 14     2.1        0.2        2.1% of 0.2      0.0042
# 15     6.7        0.3        6.7% of 0.3      0.0201
# 16     0.2      843.0      0.2% of 843.0      1.6860
# 17     2.1   586612.0   2.1% of 586612.0  12318.8520
# 18     6.1   705271.0   6.1% of 705271.0  43021.5310
# 19     4.6        0.7        4.6% of 0.7      0.0322
# 20     1.1       44.0       1.1% of 44.0      0.4840
# 21     0.6  5222246.0  0.6% of 5222246.0  31333.4760
# 22     0.2   186260.0   0.2% of 186260.0    372.5200
# 23     2.4        8.0        2.4% of 8.0      0.1920
# 24     0.2      793.0      0.2% of 793.0      1.5860
# 25     2.9      277.0      2.9% of 277.0      8.0330
# 26     0.5        0.2        0.5% of 0.2      0.0010
# 27     1.1   435059.0   1.1% of 435059.0   4785.6490
# 28     5.3        0.6        5.3% of 0.6      0.0318
# 29     5.0   776274.0   5.0% of 776274.0  38813.7000
# ...    ...        ...                ...         ...
# 19970  0.2      254.0      0.2% of 254.0      0.5080
# 19971  9.5       73.0       9.5% of 73.0      6.9350
# 19972  1.7        2.0        1.7% of 2.0      0.0340
# 19973  0.2      144.0      0.2% of 144.0      0.2880
# 19974  4.3        0.6        4.3% of 0.6      0.0258
# 19975  2.7       71.0       2.7% of 71.0      1.9170
# 19976  0.1      709.0      0.1% of 709.0      0.7090
# 19977  2.6        0.8        2.6% of 0.8      0.0208
# 19978  1.3       45.0       1.3% of 45.0      0.5850
# 19979  3.3        0.6        3.3% of 0.6      0.0198
# 19980  0.1      275.0      0.1% of 275.0      0.2750
# 19981  4.2   982661.0   4.2% of 982661.0  41271.7620
# 19982  9.4       37.0       9.4% of 37.0      3.4780
# 19983  1.8        0.4        1.8% of 0.4      0.0072
# 19984  2.4      409.0      2.4% of 409.0      9.8160
# 19985  9.2        0.0        9.2% of 0.0      0.0000
# 19986  3.8   343857.0   3.8% of 343857.0  13066.5660
# 19987  2.2        0.5        2.2% of 0.5      0.0110
# 19988  7.1        0.8        7.1% of 0.8      0.0568
# 19989  2.5   604749.0   2.5% of 604749.0  15118.7250
# 19990  4.8       98.0       4.8% of 98.0      4.7040
# 19991  2.6   400268.0   2.6% of 400268.0  10406.9680
# 19992  6.7       46.0       6.7% of 46.0      3.0820
# 19993  1.0        0.7        1.0% of 0.7      0.0070
# 19994  2.8        0.4        2.8% of 0.4      0.0112
# 19995  1.5      930.0      1.5% of 930.0     13.9500
# 19996  5.0       57.0       5.0% of 57.0      2.8500
# 19997  5.5      685.0      5.5% of 685.0     37.6750
# 19998  3.3      409.0      3.3% of 409.0     13.4970
# 19999  1.9       38.0       1.9% of 38.0      0.7220
#
# [20000 rows x 4 columns]

# %%
#now make one for division
